# %%
import pandas as pd

# %%
frutas = pd.read_table("fruit_data_with_colors.txt", sep = '\t')

# %%
frutas
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
# Número de linhas e número de colunas
frutas.shape
# Out:
# (59, 7)

# %%
# Exibir uma tabela com as 5 primeiras linhas
frutas.head(5)
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
# Algo estatístico sobre o conjunto de dados, apenas colunas numéricas
# contar / média / desvio padrão / mínimo ( menor valor encontrado) / quartis / máximo ( maior valor encontrado)
frutas.describe()
# Out:
#        fruit_label        mass      width     height  color_score
# count    59.000000   59.000000  59.000000  59.000000    59.000000
# mean      2.542373  163.118644   7.105085   7.693220     0.762881
# std       1.208048   55.018832   0.816938   1.361017     0.076857
# min       1.000000   76.000000   5.800000   4.000000     0.550000
# 25%       1.000000  140.000000   6.600000   7.200000     0.720000
# 50%       3.000000  158.000000   7.200000   7.600000     0.750000
# 75%       4.000000  177.000000   7.500000   8.200000     0.810000
# max       4.000000  362.000000   9.600000  10.500000     0.930000

# %%
frutas.describe()['mass']
# Out:
# count     59.000000
# mean     163.118644
# std       55.018832
# min       76.000000
# 25%      140.000000
# 50%      158.000000
# 75%      177.000000
# max      362.000000
# Name: mass, dtype: float64

# %%
frutas.describe()['mass']['min']
# Out:
# 76.0

# %%
frutas['mass']
# Out:
# 0     192
# 1     180
# 2     176
# 3      86
# 4      84
# 5      80
# 6      80
# 7      76
# 8     178
# 9     172
# 10    166
# 11    172
# 12    154
# 13    164
# 14    152
# 15    156
# 16    156
# 17    168
# 18    162
# 19    162
# 20    160
# 21    156
# 22    140
# 23    170
# 24    342
# 25    356
# 26    362
# 27    204
# 28    140
# 29    160
# 30    158
# 31    210
# 32    164
# 33    190
# 34    142
# 35    150
# 36    160
# 37    154
# 38    158
# 39    144
# 40    154
# 41    180
# 42    154
# 43    194
# 44    200
# 45    186
# 46    216
# 47    196
# 48    174
# 49    132
# 50    130
# 51    116
# 52    118
# 53    120
# 54    116
# 55    116
# 56    116
# 57    152
# 58    118
# Name: mass, dtype: int64

# %%
frutas[['mass', 'color_score']]
# Out:
#     mass  color_score
# 0    192         0.55
# 1    180         0.59
# 2    176         0.60
# 3     86         0.80
# 4     84         0.79
# 5     80         0.77
# 6     80         0.81
# 7     76         0.81
# 8    178         0.92
# 9    172         0.89
# 10   166         0.93
# 11   172         0.92
# 12   154         0.88
# 13   164         0.70
# 14   152         0.69
# 15   156         0.69
# 16   156         0.67
# 17   168         0.73
# 18   162         0.83
# 19   162         0.85
# 20   160         0.86
# 21   156         0.84
# 22   140         0.87
# 23   170         0.88
# 24   342         0.75
# 25   356         0.75
# 26   362         0.74
# 27   204         0.77
# 28   140         0.72
# 29   160         0.81
# 30   158         0.79
# 31   210         0.82
# 32   164         0.80
# 33   190         0.74
# 34   142         0.75
# 35   150         0.75
# 36   160         0.76
# 37   154         0.79
# 38   158         0.77
# 39   144         0.75
# ...

# %%
frutas[10:15]
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# 11            1      apple          braeburn   172    7.1     7.6         0.92
# 12            1      apple          braeburn   154    7.0     7.1         0.88
# 13            1      apple  golden_delicious   164    7.3     7.7         0.70
# 14            1      apple  golden_delicious   152    7.6     7.3         0.69

# %%
frutas[['mass', 'color_score']][10:15]
# Out:
#     mass  color_score
# 10   166         0.93
# 11   172         0.92
# 12   154         0.88
# 13   164         0.70
# 14   152         0.69
