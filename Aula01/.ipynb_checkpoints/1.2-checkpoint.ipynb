# %%
import pandas as pd

# %%
data = pd.read_table("fruit_data_with_colors_miss.txt")

# %%
data
# Out:
#     fruit_label fruit_name     fruit_subtype mass  width height  color_score
# 0             1      apple      granny_smith  192    8.4    7.3         0.55
# 1             1      apple      granny_smith  180    8.0    6.8         0.59
# 2             1      apple      granny_smith  176    7.4    7.2         0.60
# 3             2   mandarin          mandarin    ?    6.2    4.7         0.80
# 4             2   mandarin          mandarin  84     6.0    4.6         0.79
# 5             2   mandarin          mandarin  80     5.8    4.3         0.77
# 6             2   mandarin          mandarin  80     5.9    4.3         0.81
# 7             2   mandarin                 .   76    5.8    4.0         0.81
# 8             1      apple          braeburn  178    7.1      .         0.92
# 9             1      apple          braeburn  172    7.4    7.0         0.89
# 10            1      apple          braeburn  166    6.9    7.3         0.93
# ...

# %%
data.shape
# Out:
# (59, 7)

# %%
# Substituindo dados faltantes por NaN
data = pd.read_table('fruit_data_with_colors_miss.txt', na_values = ['.','?'])

# %%
data
# Out:
#     fruit_label fruit_name     fruit_subtype   mass  width  height  \
# 0             1      apple      granny_smith  192.0    8.4     7.3
# 1             1      apple      granny_smith  180.0    8.0     6.8
# 2             1      apple      granny_smith  176.0    7.4     7.2
# 3             2   mandarin          mandarin    NaN    6.2     4.7
# 4             2   mandarin          mandarin   84.0    6.0     4.6
# 5             2   mandarin          mandarin   80.0    5.8     4.3
# 6             2   mandarin          mandarin   80.0    5.9     4.3
# 7             2   mandarin               NaN   76.0    5.8     4.0
# 8             1      apple          braeburn  178.0    7.1     NaN
# 9             1      apple          braeburn  172.0    7.4     7.0
# 10            1      apple          braeburn  166.0    6.9     7.3
# 11            1      apple          braeburn  172.0    7.1     7.6
# 12            1      apple          braeburn  154.0    7.0     7.1
# ...

# %%
# Imputando dado aos valores faltantes, nesse caso substituindo por 0
data.fillna(0)
# Out:
#     fruit_label fruit_name     fruit_subtype   mass  width  height  \
# 0             1      apple      granny_smith  192.0    8.4     7.3
# 1             1      apple      granny_smith  180.0    8.0     6.8
# 2             1      apple      granny_smith  176.0    7.4     7.2
# 3             2   mandarin          mandarin    0.0    6.2     4.7
# 4             2   mandarin          mandarin   84.0    6.0     4.6
# 5             2   mandarin          mandarin   80.0    5.8     4.3
# 6             2   mandarin          mandarin   80.0    5.9     4.3
# 7             2   mandarin                 0   76.0    5.8     4.0
# 8             1      apple          braeburn  178.0    7.1     0.0
# 9             1      apple          braeburn  172.0    7.4     7.0
# 10            1      apple          braeburn  166.0    6.9     7.3
# 11            1      apple          braeburn  172.0    7.1     7.6
# 12            1      apple          braeburn  154.0    7.0     7.1
# ...

# %%
# Análise estatística básica dos dados
data.describe()
# Out:
#        fruit_label        mass      width     height  color_score
# count    59.000000   58.000000  59.000000  58.000000    59.000000
# mean      2.542373  164.448276   7.105085   7.691379     0.762881
# std       1.208048   54.534770   0.816938   1.372830     0.076857
# min       1.000000   76.000000   5.800000   4.000000     0.550000
# 25%       1.000000  140.500000   6.600000   7.200000     0.720000
# 50%       3.000000  159.000000   7.200000   7.600000     0.750000
# 75%       4.000000  177.500000   7.500000   8.200000     0.810000
# max       4.000000  362.000000   9.600000  10.500000     0.930000

# %%
# Imputando média aos valores faltantes
data.fillna(data.mean())
# Out:
#     fruit_label fruit_name     fruit_subtype        mass  width     height  \
# 0             1      apple      granny_smith  192.000000    8.4   7.300000
# 1             1      apple      granny_smith  180.000000    8.0   6.800000
# 2             1      apple      granny_smith  176.000000    7.4   7.200000
# 3             2   mandarin          mandarin  164.448276    6.2   4.700000
# 4             2   mandarin          mandarin   84.000000    6.0   4.600000
# 5             2   mandarin          mandarin   80.000000    5.8   4.300000
# 6             2   mandarin          mandarin   80.000000    5.9   4.300000
# 7             2   mandarin               NaN   76.000000    5.8   4.000000
# 8             1      apple          braeburn  178.000000    7.1   7.691379
# 9             1      apple          braeburn  172.000000    7.4   7.000000
# 10            1      apple          braeburn  166.000000    6.9   7.300000
# ...

# %%
# Elemento que foi indicado mais vezes no banco de dados
data['fruit_subtype'].value_counts().idxmax()
# Out:
# 'turkey_navel'

# %%
# Difinindo a média para colunas faltantes
data = data.fillna(data.mean())

# %%
data
# Out:
#     fruit_label fruit_name     fruit_subtype        mass  width     height  \
# 0             1      apple      granny_smith  192.000000    8.4   7.300000
# 1             1      apple      granny_smith  180.000000    8.0   6.800000
# 2             1      apple      granny_smith  176.000000    7.4   7.200000
# 3             2   mandarin          mandarin  164.448276    6.2   4.700000
# 4             2   mandarin          mandarin   84.000000    6.0   4.600000
# 5             2   mandarin          mandarin   80.000000    5.8   4.300000
# 6             2   mandarin          mandarin   80.000000    5.9   4.300000
# 7             2   mandarin               NaN   76.000000    5.8   4.000000
# 8             1      apple          braeburn  178.000000    7.1   7.691379
# 9             1      apple          braeburn  172.000000    7.4   7.000000
# 10            1      apple          braeburn  166.000000    6.9   7.300000
# ...

# %%
# Definindo na coluna fruit_subtype o valor que mais se repete para valores faltantes nela
data['fruit_subtype'] = data ['fruit_subtype'].fillna(data['fruit_subtype'].value_counts().idxmax())

# %%
data
# Out:
#     fruit_label fruit_name     fruit_subtype        mass  width     height  \
# 0             1      apple      granny_smith  192.000000    8.4   7.300000
# 1             1      apple      granny_smith  180.000000    8.0   6.800000
# 2             1      apple      granny_smith  176.000000    7.4   7.200000
# 3             2   mandarin          mandarin  164.448276    6.2   4.700000
# 4             2   mandarin          mandarin   84.000000    6.0   4.600000
# 5             2   mandarin          mandarin   80.000000    5.8   4.300000
# 6             2   mandarin          mandarin   80.000000    5.9   4.300000
# 7             2   mandarin      turkey_navel   76.000000    5.8   4.000000
# 8             1      apple          braeburn  178.000000    7.1   7.691379
# 9             1      apple          braeburn  172.000000    7.4   7.000000
# 10            1      apple          braeburn  166.000000    6.9   7.300000
# ...

# %% [markdown]
# # -

# %%
data = pd.read_table('fruit_data_with_colors_miss.txt', na_values = ['.','?'])

# %%
data
# Out:
#     fruit_label fruit_name     fruit_subtype   mass  width  height  \
# 0             1      apple      granny_smith  192.0    8.4     7.3
# 1             1      apple      granny_smith  180.0    8.0     6.8
# 2             1      apple      granny_smith  176.0    7.4     7.2
# 3             2   mandarin          mandarin    NaN    6.2     4.7
# 4             2   mandarin          mandarin   84.0    6.0     4.6
# 5             2   mandarin          mandarin   80.0    5.8     4.3
# 6             2   mandarin          mandarin   80.0    5.9     4.3
# 7             2   mandarin               NaN   76.0    5.8     4.0
# 8             1      apple          braeburn  178.0    7.1     NaN
# 9             1      apple          braeburn  172.0    7.4     7.0
# 10            1      apple          braeburn  166.0    6.9     7.3
# 11            1      apple          braeburn  172.0    7.1     7.6
# 12            1      apple          braeburn  154.0    7.0     7.1
# ...

# %%
# Indice 0 = número de linhas
data.shape[0]
# Out:
# 59

# %%
# Todas colunas e quantidades de dados faltantes em cada coluna
data.isnull().sum()
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    1
# mass             1
# width            0
# height           1
# color_score      0
# dtype: int64

# %%
# Se a quantidade de dar faltantes for superior a 25% eliminamos a coluna

# %%
# Calcular porcentagem de dados faltantes
data.isnull().sum()/data.shape[0] * 100
# Out:
# fruit_label      0.000000
# fruit_name       0.000000
# fruit_subtype    1.694915
# mass             1.694915
# width            0.000000
# height           1.694915
# color_score      0.000000
# dtype: float64

# %%
# Excluindo a coluna mass, definindo todas as colunas com exceção da mass na variável data
data = data[['fruit_label','fruit_name','fruit_subtype','width','height','color_score']]

# %%
data
# Out:
#     fruit_label fruit_name     fruit_subtype  width  height  color_score
# 0             1      apple      granny_smith    8.4     7.3         0.55
# 1             1      apple      granny_smith    8.0     6.8         0.59
# 2             1      apple      granny_smith    7.4     7.2         0.60
# 3             2   mandarin          mandarin    6.2     4.7         0.80
# 4             2   mandarin          mandarin    6.0     4.6         0.79
# 5             2   mandarin          mandarin    5.8     4.3         0.77
# 6             2   mandarin          mandarin    5.9     4.3         0.81
# 7             2   mandarin               NaN    5.8     4.0         0.81
# 8             1      apple          braeburn    7.1     NaN         0.92
# 9             1      apple          braeburn    7.4     7.0         0.89
# 10            1      apple          braeburn    6.9     7.3         0.93
# 11            1      apple          braeburn    7.1     7.6         0.92
# ...

# %% [markdown]
# ### Transformando a escala dos dados

# %%
data = pd.read_table('fruit_data_with_colors_miss.txt', na_values = ['.','?']) # substituindo por NaN
data = data.fillna(data.mean()) # transformando dados faltantes na sua média
data = data [['mass','width','height','color_score']] # seleção das colunas com dados númericos

# %%
data
# Out:
#           mass  width     height  color_score
# 0   192.000000    8.4   7.300000         0.55
# 1   180.000000    8.0   6.800000         0.59
# 2   176.000000    7.4   7.200000         0.60
# 3   164.448276    6.2   4.700000         0.80
# 4    84.000000    6.0   4.600000         0.79
# 5    80.000000    5.8   4.300000         0.77
# 6    80.000000    5.9   4.300000         0.81
# 7    76.000000    5.8   4.000000         0.81
# 8   178.000000    7.1   7.691379         0.92
# 9   172.000000    7.4   7.000000         0.89
# 10  166.000000    6.9   7.300000         0.93
# 11  172.000000    7.1   7.600000         0.92
# 12  154.000000    7.0   7.100000         0.88
# 13  164.000000    7.3   7.700000         0.70
# 14  152.000000    7.6   7.300000         0.69
# 15  156.000000    7.7   7.100000         0.69
# 16  156.000000    7.6   7.500000         0.67
# 17  168.000000    7.5   7.600000         0.73
# 18  162.000000    7.5   7.100000         0.83
# ...

# %%
data.describe()
# Out:
#              mass      width     height  color_score
# count   59.000000  59.000000  59.000000    59.000000
# mean   164.448276   7.105085   7.691379     0.762881
# std     54.062599   0.816938   1.360943     0.076857
# min     76.000000   5.800000   4.000000     0.550000
# 25%    141.000000   6.600000   7.200000     0.720000
# 50%    160.000000   7.200000   7.600000     0.750000
# 75%    177.000000   7.500000   8.200000     0.810000
# max    362.000000   9.600000  10.500000     0.930000

# %%
# (valor - min) / (max- min)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm = MinMaxScaler()

# %%
mm.fit(data)
# Out:
# MinMaxScaler()

# %%
data_escala = mm.transform(data)

# %%
data_escala
# Out:
# array([[0.40559441, 0.68421053, 0.50769231, 0.        ],
#        [0.36363636, 0.57894737, 0.43076923, 0.10526316],
#        [0.34965035, 0.42105263, 0.49230769, 0.13157895],
#        [0.30925971, 0.10526316, 0.10769231, 0.65789474],
#        [0.02797203, 0.05263158, 0.09230769, 0.63157895],
#        [0.01398601, 0.        , 0.04615385, 0.57894737],
#        [0.01398601, 0.02631579, 0.04615385, 0.68421053],
#        [0.        , 0.        , 0.        , 0.68421053],
#        [0.35664336, 0.34210526, 0.56790451, 0.97368421],
#        [0.33566434, 0.42105263, 0.46153846, 0.89473684],
#        [0.31468531, 0.28947368, 0.50769231, 1.        ],
#        [0.33566434, 0.34210526, 0.55384615, 0.97368421],
#        [0.27272727, 0.31578947, 0.47692308, 0.86842105],
#        [0.30769231, 0.39473684, 0.56923077, 0.39473684],
#        [0.26573427, 0.47368421, 0.50769231, 0.36842105],
#        [0.27972028, 0.5       , 0.47692308, 0.36842105],
# ...

# %% [markdown]
# ### Eliminando outliers

# %%
data = pd.read_table('fruit_data_with_colors_miss.txt', na_values = ['.','?']) 
data = data.fillna(data.mean())

# %%
macas = data[data['fruit_name'] == 'apple']

# %%
macas
# Out:
#     fruit_label fruit_name     fruit_subtype   mass  width    height  \
# 0             1      apple      granny_smith  192.0    8.4  7.300000
# 1             1      apple      granny_smith  180.0    8.0  6.800000
# 2             1      apple      granny_smith  176.0    7.4  7.200000
# 8             1      apple          braeburn  178.0    7.1  7.691379
# 9             1      apple          braeburn  172.0    7.4  7.000000
# 10            1      apple          braeburn  166.0    6.9  7.300000
# 11            1      apple          braeburn  172.0    7.1  7.600000
# 12            1      apple          braeburn  154.0    7.0  7.100000
# 13            1      apple  golden_delicious  164.0    7.3  7.700000
# 14            1      apple  golden_delicious  152.0    7.6  7.300000
# 15            1      apple  golden_delicious  156.0    7.7  7.100000
# 16            1      apple  golden_delicious  156.0    7.6  7.500000
# 17            1      apple  golden_delicious  168.0    7.5  7.600000
# ...

# %%
macas.describe()
# Out:
#        fruit_label        mass      width     height  color_score
# count         19.0   19.000000  19.000000  19.000000    19.000000
# mean           1.0  165.052632   7.457895   7.336388     0.783684
# std            0.0   11.969747   0.345311   0.282648     0.124196
# min            1.0  140.000000   6.900000   6.800000     0.550000
# 25%            1.0  156.000000   7.300000   7.100000     0.690000
# 50%            1.0  164.000000   7.400000   7.300000     0.840000
# 75%            1.0  172.000000   7.600000   7.550000     0.880000
# max            1.0  192.000000   8.400000   7.900000     0.930000
